# %%
import pandas as pd

# %%
housing_df = pd.read_csv(r'C:\Users\DIVYA SONI\Downloads\Boston.csv')

# %%
housing_df
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 0             1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900
# 1             2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671
# 2             3   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671
# 3             4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622
# 4             5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622
# 5             6   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622
# 6             7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605
# 7             8   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505
# 8             9   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821
# 9            10   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921
# 10           11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467
# 11           12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267
# 12           13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509
# 13           14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075
# 14           15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619
# 15           16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986
# 16           17   1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986
# 17           18   0.78420   0.0   8.14     0  0.538  5.990   81.7  4.2579
# 18           19   0.80271   0.0   8.14     0  0.538  5.456   36.6  3.7965
# 19           20   0.72580   0.0   8.14     0  0.538  5.727   69.5  3.7965
# 20           21   1.25179   0.0   8.14     0  0.538  5.570   98.1  3.7979
# 21           22   0.85204   0.0   8.14     0  0.538  5.965   89.2  4.0123
# 22           23   1.23247   0.0   8.14     0  0.538  6.142   91.7  3.9769
# 23           24   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952
# 24           25   0.75026   0.0   8.14     0  0.538  5.924   94.1  4.3996
# 25           26   0.84054   0.0   8.14     0  0.538  5.599   85.7  4.4546
# 26           27   0.67191   0.0   8.14     0  0.538  5.813   90.3  4.6820
# 27           28   0.95577   0.0   8.14     0  0.538  6.047   88.8  4.4534
# 28           29   0.77299   0.0   8.14     0  0.538  6.495   94.4  4.4547
# 29           30   1.00245   0.0   8.14     0  0.538  6.674   87.3  4.2390
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 476         477   4.87141   0.0  18.10     0  0.614  6.484   93.6  2.3053
# 477         478  15.02340   0.0  18.10     0  0.614  5.304   97.3  2.1007
# 478         479  10.23300   0.0  18.10     0  0.614  6.185   96.7  2.1705
# 479         480  14.33370   0.0  18.10     0  0.614  6.229   88.0  1.9512
# 480         481   5.82401   0.0  18.10     0  0.532  6.242   64.7  3.4242
# 481         482   5.70818   0.0  18.10     0  0.532  6.750   74.9  3.3317
# 482         483   5.73116   0.0  18.10     0  0.532  7.061   77.0  3.4106
# 483         484   2.81838   0.0  18.10     0  0.532  5.762   40.3  4.0983
# 484         485   2.37857   0.0  18.10     0  0.583  5.871   41.9  3.7240
# 485         486   3.67367   0.0  18.10     0  0.583  6.312   51.9  3.9917
# 486         487   5.69175   0.0  18.10     0  0.583  6.114   79.8  3.5459
# 487         488   4.83567   0.0  18.10     0  0.583  5.905   53.2  3.1523
# 488         489   0.15086   0.0  27.74     0  0.609  5.454   92.7  1.8209
# 489         490   0.18337   0.0  27.74     0  0.609  5.414   98.3  1.7554
# 490         491   0.20746   0.0  27.74     0  0.609  5.093   98.0  1.8226
# 491         492   0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681
# 492         493   0.11132   0.0  27.74     0  0.609  5.983   83.5  2.1099
# 493         494   0.17331   0.0   9.69     0  0.585  5.707   54.0  2.3817
# 494         495   0.27957   0.0   9.69     0  0.585  5.926   42.6  2.3817
# 495         496   0.17899   0.0   9.69     0  0.585  5.670   28.8  2.7986
# 496         497   0.28960   0.0   9.69     0  0.585  5.390   72.9  2.7986
# 497         498   0.26838   0.0   9.69     0  0.585  5.794   70.6  2.8927
# 498         499   0.23912   0.0   9.69     0  0.585  6.019   65.3  2.4091
# 499         500   0.17783   0.0   9.69     0  0.585  5.569   73.5  2.3999
# 500         501   0.22438   0.0   9.69     0  0.585  6.027   79.7  2.4982
# 501         502   0.06263   0.0  11.93     0  0.573  6.593   69.1  2.4786
# 502         503   0.04527   0.0  11.93     0  0.573  6.120   76.7  2.2875
# 503         504   0.06076   0.0  11.93     0  0.573  6.976   91.0  2.1675
# 504         505   0.10959   0.0  11.93     0  0.573  6.794   89.3  2.3889
# 505         506   0.04741   0.0  11.93     0  0.573  6.030   80.8  2.5050
#
#      rad  tax  ptratio   black  lstat  medv
# 0      1  296     15.3  396.90   4.98  24.0
# 1      2  242     17.8  396.90   9.14  21.6
# 2      2  242     17.8  392.83   4.03  34.7
# 3      3  222     18.7  394.63   2.94  33.4
# 4      3  222     18.7  396.90   5.33  36.2
# 5      3  222     18.7  394.12   5.21  28.7
# 6      5  311     15.2  395.60  12.43  22.9
# 7      5  311     15.2  396.90  19.15  27.1
# 8      5  311     15.2  386.63  29.93  16.5
# 9      5  311     15.2  386.71  17.10  18.9
# 10     5  311     15.2  392.52  20.45  15.0
# 11     5  311     15.2  396.90  13.27  18.9
# 12     5  311     15.2  390.50  15.71  21.7
# 13     4  307     21.0  396.90   8.26  20.4
# 14     4  307     21.0  380.02  10.26  18.2
# 15     4  307     21.0  395.62   8.47  19.9
# 16     4  307     21.0  386.85   6.58  23.1
# 17     4  307     21.0  386.75  14.67  17.5
# 18     4  307     21.0  288.99  11.69  20.2
# 19     4  307     21.0  390.95  11.28  18.2
# 20     4  307     21.0  376.57  21.02  13.6
# 21     4  307     21.0  392.53  13.83  19.6
# 22     4  307     21.0  396.90  18.72  15.2
# 23     4  307     21.0  394.54  19.88  14.5
# 24     4  307     21.0  394.33  16.30  15.6
# 25     4  307     21.0  303.42  16.51  13.9
# 26     4  307     21.0  376.88  14.81  16.6
# 27     4  307     21.0  306.38  17.28  14.8
# 28     4  307     21.0  387.94  12.80  18.4
# 29     4  307     21.0  380.23  11.98  21.0
# ..   ...  ...      ...     ...    ...   ...
# 476   24  666     20.2  396.21  18.68  16.7
# 477   24  666     20.2  349.48  24.91  12.0
# 478   24  666     20.2  379.70  18.03  14.6
# 479   24  666     20.2  383.32  13.11  21.4
# 480   24  666     20.2  396.90  10.74  23.0
# 481   24  666     20.2  393.07   7.74  23.7
# 482   24  666     20.2  395.28   7.01  25.0
# 483   24  666     20.2  392.92  10.42  21.8
# 484   24  666     20.2  370.73  13.34  20.6
# 485   24  666     20.2  388.62  10.58  21.2
# 486   24  666     20.2  392.68  14.98  19.1
# 487   24  666     20.2  388.22  11.45  20.6
# 488    4  711     20.1  395.09  18.06  15.2
# 489    4  711     20.1  344.05  23.97   7.0
# 490    4  711     20.1  318.43  29.68   8.1
# 491    4  711     20.1  390.11  18.07  13.6
# 492    4  711     20.1  396.90  13.35  20.1
# 493    6  391     19.2  396.90  12.01  21.8
# 494    6  391     19.2  396.90  13.59  24.5
# 495    6  391     19.2  393.29  17.60  23.1
# 496    6  391     19.2  396.90  21.14  19.7
# 497    6  391     19.2  396.90  14.10  18.3
# 498    6  391     19.2  396.90  12.92  21.2
# 499    6  391     19.2  395.77  15.10  17.5
# 500    6  391     19.2  396.90  14.33  16.8
# 501    1  273     21.0  391.99   9.67  22.4
# 502    1  273     21.0  396.90   9.08  20.6
# 503    1  273     21.0  396.90   5.64  23.9
# 504    1  273     21.0  393.45   6.48  22.0
# 505    1  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
housing_df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
housing_df.describe()
# Count tells us the number of rows with actual values.
# Mean is simply the sum of each entry divided by the no. of entries.
# STD is standard deviation, no. of units that are expected to deviate from the mean.
# Min is the smallest entry in each column.
# 25% is first quartile, 25% of the data has a value less than this no.
# 50% is the median, halfway mark of the data i.e.half of the is higher than this value and half is lower.
# 75% is third quartile, 75% of this data has the value less than this.
# max is the largest entry in each column .
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# min      3.561000    2.900000    1.129600    1.000000  187.000000   12.600000
# 25%      5.885500   45.025000    2.100175    4.000000  279.000000   17.400000
# 50%      6.208500   77.500000    3.207450    5.000000  330.000000   19.050000
# 75%      6.623500   94.075000    5.188425   24.000000  666.000000   20.200000
# max      8.780000  100.000000   12.126500   24.000000  711.000000   22.000000
#
#             black       lstat        medv
# count  506.000000  506.000000  506.000000
# mean   356.674032   12.653063   22.532806
# std     91.294864    7.141062    9.197104
# min      0.320000    1.730000    5.000000
# 25%    375.377500    6.950000   17.025000
# 50%    391.440000   11.360000   21.200000
# 75%    396.225000   16.955000   25.000000
# max    396.900000   37.970000   50.000000

# %%
housing_df.info()
# This gives us the full list of the columns at once.
# there are total 506 rows and 15 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
# Unnamed: 0    506 non-null int64
# crim          506 non-null float64
# zn            506 non-null float64
# indus         506 non-null float64
# chas          506 non-null int64
# nox           506 non-null float64
# rm            506 non-null float64
# age           506 non-null float64
# dis           506 non-null float64
# rad           506 non-null int64
# tax           506 non-null int64
# ptratio       506 non-null float64
# black         506 non-null float64
# lstat         506 non-null float64
# medv          506 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
housing_df.shape
# It doesnt need parethesis because it's technicall an attribute and pre-computed.
# Out:
# (506, 15)

# %%
housing_df.isnull().any()
# We can only select the columns that are null values in the dataset.
# isnull() displays an entire dataframes with true/false values.
# any() return the indivual columns.
# Out:
# Unnamed: 0    False
# crim          False
# zn            False
# indus         False
# chas          False
# nox           False
# rm            False
# age           False
# dis           False
# rad           False
# tax           False
# ptratio       False
# black         False
# lstat         False
# medv          False
# dtype: bool

# %%
housing_df.loc[:5, housing_df.isnull().any()]
# We're usingloc to find the location of particular rows.
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
housing_df.loc[:, housing_df.isnull().any()].describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-1f0e4dae593c> in <module>
# ----> 1 housing_df.loc[:, housing_df.isnull().any()].describe()
#
# c:\users\divya soni\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9719             raise NotImplementedError(msg)
#    9720         elif self.ndim == 2 and self.columns.size == 0:
# -> 9721             raise ValueError("Cannot describe a DataFrame without columns")
#    9722
#    9723         if percentiles is not None:
#
# ValueError: Cannot describe a DataFrame without columns

# %% [markdown]
# # Replacing Null Values
#
# Pandas include a nice method, fillna, which can be used to replace null values. It works for individual columns and entire DataFrames. We will use three approaches, replacing the null values of a column with the mean, replacing the null values of a column with another value, and replacing all the null values in the entire dataset with the median.

# %%
# Replace null column values with mean:
housing_df['age'] = housing_df['age'].fillna(housing_df.mean())

# %%
# Then, replace null column values with a value (0 in this case):
housing_df['chas'] = housing_df['chas'].fillna(0)

# %%
#Replace null DataFrame values with median:

housing_df = housing_df.fillna(housing_df.median())

# %%
#Finally, check that all null values have been replaced:

housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
# Unnamed: 0    506 non-null int64
# crim          506 non-null float64
# zn            506 non-null float64
# indus         506 non-null float64
# chas          506 non-null int64
# nox           506 non-null float64
# rm            506 non-null float64
# age           506 non-null float64
# dis           506 non-null float64
# rad           506 non-null int64
# tax           506 non-null int64
# ptratio       506 non-null float64
# black         506 non-null float64
# lstat         506 non-null float64
# medv          506 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# # Plotting Histogram

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# (That second line)It basically shows all graphs within Jupyter Notebooks instead of exporting them to external files.
# It's used when you want to see the graphs right there in front of you.

# %%
import seaborn as sns
# Set up seaborn dark grid
sns.set()

# %%
plt.hist(housing_df['medv'])
plt.show()

# %%
plt.hist(housing_df['medv'])
plt.title('Median Boston Housing Prices')
plt.xlabel('1980 Median Value in Thousand')
plt.ylabel('Count')
plt.show()

# %%
title = 'Median Boston Housing Prices'
plt.figure(figsize = (12,7))
plt.hist(housing_df['medv'])
plt.title(title,fontsize = 30)
plt.xlabel('1980 Median Value in Thousand', fontsize = 18)
plt.ylabel('Count', fontsize = 18)
plt.savefig(title, dpi = 300)
plt.show()

# %%
# Defining a histogram function:
def my_hist(column, title, xlab, ylab):
    plt.figure(figsize=(10,6))
    plt.hist(column)
    plt.title(title, fontsize=15)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.savefig(title, dpi=300)
    plt.show()

# %%
my_hist(housing_df['rm'], 'Average Number of Rooms in Boston Households', 'Average Number of Rooms', 'Count')

# %%
def my_hist(column, title, xlab, ylab, bins=10, alpha=0.7, color='c'): #alpha is the transparency
    title = title
    plt.figure(figsize=(10,6))
    plt.hist(column, bins=bins, range=(3,9), alpha=alpha, color=color)
    plt.title(title, fontsize=15)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.savefig(title, dpi=300)
    plt.show()

# %%
my_hist(housing_df['rm'], 'Average Number of Rooms in Boston', 'Average Number of Rooms', 'Count', bins=6)

# %% [markdown]
# # Scatter Plot

# %%
x = housing_df['rm']
y = housing_df['medv']
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Correlation
#
# Correlation is a statistical measure between -1 and +1 that indicates how closely two variables are related. A correlation of -1 or +1 means that variables are completely dependent, and they fall in a perfectly straight line. A correlation of 0 indicates that an increase in one variable gives no information whatsoever about the other variable. Visually, this would be points all over the place. Correlations usually fall somewhere in the middle. For instance, a correlation of 0.75 represents a fairly strong relationship, whereas a correlation of 0.25 is a reasonably weak relationship. Positive correlations go up (meaning as x goes up, y goes up), and negative correlations go down.

# %%
housing_df.corr()
# Out:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ptratio       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# black        -0.295041 -0.385064  0.175520 -0.356977  0.048788 -0.380051
# lstat         0.258465  0.455621 -0.412995  0.603800 -0.053929  0.590879
# medv         -0.226604 -0.388305  0.360445 -0.483725  0.175260 -0.427321
#
#                   rm       age       dis       rad       tax   ptratio  \
# Unnamed: 0 -0.079971  0.203784 -0.302211  0.686002  0.666626  0.291074
# crim       -0.219247  0.352734 -0.379670  0.625505  0.582764  0.289946
# zn          0.311991 -0.569537  0.664408 -0.311948 -0.314563 -0.391679
# indus      -0.391676  0.644779 -0.708027  0.595129  0.720760  0.383248
# chas        0.091251  0.086518 -0.099176 -0.007368 -0.035587 -0.121515
# nox        -0.302188  0.731470 -0.769230  0.611441  0.668023  0.188933
# rm          1.000000 -0.240265  0.205246 -0.209847 -0.292048 -0.355501
# age        -0.240265  1.000000 -0.747881  0.456022  0.506456  0.261515
# dis         0.205246 -0.747881  1.000000 -0.494588 -0.534432 -0.232471
# rad        -0.209847  0.456022 -0.494588  1.000000  0.910228  0.464741
# tax        -0.292048  0.506456 -0.534432  0.910228  1.000000  0.460853
# ptratio    -0.355501  0.261515 -0.232471  0.464741  0.460853  1.000000
# black       0.128069 -0.273534  0.291512 -0.444413 -0.441808 -0.177383
# lstat      -0.613808  0.602339 -0.496996  0.488676  0.543993  0.374044
# medv        0.695360 -0.376955  0.249929 -0.381626 -0.468536 -0.507787
#
#                black     lstat      medv
# Unnamed: 0 -0.295041  0.258465 -0.226604
# crim       -0.385064  0.455621 -0.388305
# zn          0.175520 -0.412995  0.360445
# indus      -0.356977  0.603800 -0.483725
# chas        0.048788 -0.053929  0.175260
# nox        -0.380051  0.590879 -0.427321
# rm          0.128069 -0.613808  0.695360
# age        -0.273534  0.602339 -0.376955
# dis         0.291512 -0.496996  0.249929
# rad        -0.444413  0.488676 -0.381626
# tax        -0.441808  0.543993 -0.468536
# ptratio    -0.177383  0.374044 -0.507787
# black       1.000000 -0.366087  0.333461
# lstat      -0.366087  1.000000 -0.737663
# medv        0.333461 -0.737663  1.000000

# %%
corr = housing_df.corr()
plt.figure(figsize = (7,7))
sns.heatmap(corr,xticklabels = corr.columns.values,yticklabels = corr.columns.values,cmap = "Greens", linewidth = 1.25, alpha = 0.8)
plt.show()

# %% [markdown]
# # Regression
#
# In statistics, a regression line is a line that tries to fit the values of a scatter plot as closely as possible. Generally speaking, a good regression line has half of the points above the line, and the other half are below it. The most popular regression line method is the ordinary least squares method, which tries to measure the error between prediction and true data by computing the sum of the square of the distance from each point to the corresponding prediction on the line and iteratively tries to reduce it.

# %%
plt.figure(figsize =(10,7))
sns.regplot(x, y)
plt.show()

# %% [markdown]
# We may wonder about the shaded part of the line. It represents a 95% confidence interval, meaning that Python is 95% confident that the actual regression line falls within that range. Since the shaded area is fairly small in relation to the plot, this means that the regression line is reasonably accurate.
#
# The general idea behind regression lines is that they can be used to predict new y values from new x values. For instance, if there is an eight-room house, you can use regression to get an estimate of its value.

# %% [markdown]
# # StatsModel Regression Output
#
# We will import StatsModel and use its methods to print out a summary of the regression line:

# %%
import statsmodels.api as sm
X = sm.add_constant(x)
model = sm.OLS(y,x)
est = model.fit()
print(est.summary())

# %% [markdown]
# There's a lot of important information in this table. The first is the value of R^2 at 0.484. This suggests that 48% of the variance of the data can be explained by the regression line. The second is the coefficient constant of -34.6706. This is the y-intercept. The third is the RM coefficient of 9.1021. This suggests that for every one-bedroom increase, the value of the house increased by 9.102. (Keep in mind that this dataset is from 1980.)
#
# The standard error suggests how far off the actual values are from the line on average, and the numbers underneath the [0.025 0.975] column give the 95% Confidence Interval of the value, meaning statsmodel is 95% confident that the true increase in the value of the average house for every one-bedroom increase is between 8.279 and 9.925.

# %% [markdown]
# # Box Plot

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# Note that the open circles are considered outliers. The orange bar in the middle is the median, and the bars at the end of the black box are the 25th and 75th percentiles, or the 1st and 3rd quartiles, respectively. The end bars represent the quartiles plus or minus 1.5 times the interquartile range. The value of 1.5 times the interquartile range is a standard limit in statistics used to define outliers. In this exercise, you created a box plot graph to represent the graph.

# %% [markdown]
# # Violin Plot

# %%
plt.violinplot(x)
plt.show()

# %% [markdown]
# In the violin plot, the upper and lower bars define the minimum and maximum values, and the width of the plot indicates how many rows contain that particular value. The difference between the violin plot and the box plot is that the violin plot shows the overall distribution of the data.
